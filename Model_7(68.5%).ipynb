# %% [markdown]
# # **Working with a new dataset: CIFAR-10**
#
# The CIFAR-10 dataset consists of 60000 32x32 colour images in 10 classes, with 6000 images per class. There are 50000 training images and 10000 test images. More information about CIFAR-10 can be found [here](https://www.cs.toronto.edu/~kriz/cifar.html).
#
# In Keras, the CIFAR-10 dataset is also preloaded in the form of four Numpy arrays. x_train and y_train contain the training set, while x_test and y_test contain the test data. The images are encoded as Numpy arrays and their corresponding labels ranging from 0 to 9.

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical

# Load CIFAR-10 dataset
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 13s 0us/step

# %%
# Class names
classes = ['airplane','automobile','bird','cat','deer',
           'dog','frog','horse','ship','truck']

# Create 10x10 grid
plt.figure(figsize=(10,10))

for class_idx in range(10):
  # Get indices of this class (finds images of a specific class)
  idx = np.where(y_train.flatten() == class_idx)[0]

  # Pick 10 random samples
  random_idx = np.random.choice(idx, 10, replace=False)

  for i, idx in enumerate(random_idx):
    plt_idx = class_idx * 10 + i + 1
    plt.subplot(10, 10, plt_idx)
    plt.imshow(x_train[idx])
    plt.axis('off')

    # Show class name clearly on the left
    if i == 0:
      plt.text(-5, 15, classes[class_idx], fontsize=12, ha='right')

plt.subplots_adjust(left=0.15)  # creates space so labels aren’t cut off
plt.show()

# Convert the labels to one-hot encoded form.
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# Normalize the images
x_train_normalized = x_train.astype('float32') / 255.0
x_test_normalized = x_test.astype('float32') / 255.0

# %%
from keras.backend import clear_session
clear_session()

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

base_model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(100, activation='relu'),
    Dense(10, activation='softmax')
])

base_model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 30, 30, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 15, 15, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 7200)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 100)            │       720,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         1,010 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 722,006 (2.75 MB)
#  Trainable params: 722,006 (2.75 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the model
base_model.compile(
    loss='categorical_crossentropy',
    optimizer='SGD',
    metrics=['accuracy']
)

# Train the model
history = base_model.fit(
    x_train_normalized,
    y_train,
    epochs=50,
    batch_size=512,
    validation_split=0.2,
)
# Out:
# Epoch 1/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - accuracy: 0.1649 - loss: 2.2649 - val_accuracy: 0.2036 - val_loss: 2.2182
# Epoch 2/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.2315 - loss: 2.1677 - val_accuracy: 0.2225 - val_loss: 2.1215
# Epoch 3/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.2649 - loss: 2.0632 - val_accuracy: 0.2670 - val_loss: 2.0360
# Epoch 4/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.3020 - loss: 1.9876 - val_accuracy: 0.2884 - val_loss: 1.9809
# Epoch 5/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3235 - loss: 1.9375 - val_accuracy: 0.2694 - val_loss: 2.0042
# Epoch 6/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3366 - loss: 1.9012 - val_accuracy: 0.3008 - val_loss: 1.9356
# Epoch 7/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.3480 - loss: 1.8725 - val_accuracy: 0.2878 - val_loss: 1.9722
# Epoch 8/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.3583 - loss: 1.8470 - val_accuracy: 0.3314 - val_loss: 1.8909
# Epoch 9/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.3693 - loss: 1.8222 - val_accuracy: 0.3534 - val_loss: 1.8374
# Epoch 10/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.3734 - loss: 1.8021 - val_accuracy: 0.3423 - val_loss: 1.8500
# Epoch 11/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.3819 - loss: 1.7796 - val_accuracy: 0.3290 - val_loss: 1.8706
# Epoch 12/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.3879 - loss: 1.7631 - val_accuracy: 0.3398 - val_loss: 1.8403
# Epoch 13/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.3925 - loss: 1.7458 - val_accuracy: 0.3712 - val_loss: 1.7954
# Epoch 14/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.3987 - loss: 1.7279 - val_accuracy: 0.3764 - val_loss: 1.7920
# Epoch 15/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.4063 - loss: 1.7084 - val_accuracy: 0.3893 - val_loss: 1.7270
# Epoch 16/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.4093 - loss: 1.6925 - val_accuracy: 0.3743 - val_loss: 1.7488
# Epoch 17/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.4153 - loss: 1.6770 - val_accuracy: 0.3744 - val_loss: 1.7379
# Epoch 18/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.4211 - loss: 1.6577 - val_accuracy: 0.3731 - val_loss: 1.7588
# Epoch 19/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.4245 - loss: 1.6480 - val_accuracy: 0.3646 - val_loss: 1.7883
# Epoch 20/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.4303 - loss: 1.6323 - val_accuracy: 0.4254 - val_loss: 1.6418
# Epoch 21/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.4346 - loss: 1.6180 - val_accuracy: 0.3892 - val_loss: 1.6862
# Epoch 22/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.4410 - loss: 1.6011 - val_accuracy: 0.3921 - val_loss: 1.6718
# Epoch 23/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.4419 - loss: 1.5920 - val_accuracy: 0.3975 - val_loss: 1.6861
# Epoch 24/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4468 - loss: 1.5828 - val_accuracy: 0.4029 - val_loss: 1.6580
# Epoch 25/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.4521 - loss: 1.5659 - val_accuracy: 0.4102 - val_loss: 1.6262
# Epoch 26/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.4530 - loss: 1.5560 - val_accuracy: 0.4077 - val_loss: 1.6599
# Epoch 27/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4572 - loss: 1.5403 - val_accuracy: 0.3995 - val_loss: 1.6790
# Epoch 28/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.4642 - loss: 1.5244 - val_accuracy: 0.3759 - val_loss: 1.7259
# Epoch 29/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.4646 - loss: 1.5207 - val_accuracy: 0.3362 - val_loss: 1.8363
# Epoch 30/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.4700 - loss: 1.5073 - val_accuracy: 0.4280 - val_loss: 1.6032
# Epoch 31/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4737 - loss: 1.4948 - val_accuracy: 0.4058 - val_loss: 1.6689
# Epoch 32/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.4785 - loss: 1.4818 - val_accuracy: 0.4086 - val_loss: 1.6198
# Epoch 33/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4837 - loss: 1.4707 - val_accuracy: 0.4289 - val_loss: 1.5829
# Epoch 34/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4878 - loss: 1.4579 - val_accuracy: 0.4484 - val_loss: 1.5315
# Epoch 35/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.4877 - loss: 1.4538 - val_accuracy: 0.4295 - val_loss: 1.5594
# Epoch 36/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4949 - loss: 1.4352 - val_accuracy: 0.4704 - val_loss: 1.5081
# Epoch 37/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.4974 - loss: 1.4287 - val_accuracy: 0.4560 - val_loss: 1.5180
# Epoch 38/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5020 - loss: 1.4153 - val_accuracy: 0.4509 - val_loss: 1.5313
# Epoch 39/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5065 - loss: 1.4001 - val_accuracy: 0.4559 - val_loss: 1.4983
# Epoch 40/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5100 - loss: 1.3972 - val_accuracy: 0.4635 - val_loss: 1.5022
# Epoch 41/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5111 - loss: 1.3851 - val_accuracy: 0.4586 - val_loss: 1.4922
# Epoch 42/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5127 - loss: 1.3809 - val_accuracy: 0.4686 - val_loss: 1.4737
# Epoch 43/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5191 - loss: 1.3652 - val_accuracy: 0.4536 - val_loss: 1.5253
# Epoch 44/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5229 - loss: 1.3581 - val_accuracy: 0.4660 - val_loss: 1.4960
# Epoch 45/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5217 - loss: 1.3556 - val_accuracy: 0.4758 - val_loss: 1.4430
# Epoch 46/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5271 - loss: 1.3441 - val_accuracy: 0.4748 - val_loss: 1.4482
# Epoch 47/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5282 - loss: 1.3328 - val_accuracy: 0.4820 - val_loss: 1.4552
# Epoch 48/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5350 - loss: 1.3229 - val_accuracy: 0.4924 - val_loss: 1.4791
# Epoch 49/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5353 - loss: 1.3217 - val_accuracy: 0.5099 - val_loss: 1.3816
# Epoch 50/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5407 - loss: 1.3085 - val_accuracy: 0.5248 - val_loss: 1.3585

# %%
plt.figure(figsize=(12,5))

# Loss plot
plt.subplot(1,2,1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Cross-Entropy Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Accuracy plot
plt.subplot(1,2,2)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %%
test_loss, test_accuracy = base_model.evaluate(x_test_normalized, y_test)

print("Test Accuracy for base model:", test_accuracy)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5238 - loss: 1.3375
# Test Accuracy for base model: 0.5238000154495239

# %%
# Save model
base_model.save("base_model.keras")

# %%
from keras.backend import clear_session
clear_session()

# %%
import keras
load_model = keras.saving.load_model("base_model.keras")
load_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 30, 30, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 15, 15, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 7200)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 100)            │       720,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         1,010 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 722,008 (2.75 MB)
#  Trainable params: 722,006 (2.75 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 2 (12.00 B)

# %%
from tensorflow.keras.layers import Dropout, BatchNormalization

#Create Layers
model_7 = keras.Sequential([
    Conv2D(32, (3,3), activation="relu", input_shape=(32,32,3)),
    MaxPooling2D((2,2)),

    Conv2D(64, (3,3), activation="relu"),
    MaxPooling2D((2,2)),

    Flatten(),
    Dense(100, activation="relu"),
    Dense(10, activation="softmax")
])


model_7.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 30, 30, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 15, 15, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 13, 13, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 6, 6, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 2304)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 100)            │       230,500 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         1,010 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 250,902 (980.09 KB)
#  Trainable params: 250,902 (980.09 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
#Compile Model
model_7.compile(
    optimizer="adam",
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

# Train the model
early_stopping = keras.callbacks.EarlyStopping(
    monitor="val_loss",
    patience=5,
    restore_best_weights=True
)

history_7 = model_7.fit(
    x_train_normalized,
    y_train,
    epochs=50,
    batch_size=256,
    validation_split=0.2,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 25ms/step - accuracy: 0.3835 - loss: 1.7189 - val_accuracy: 0.4622 - val_loss: 1.4896
# Epoch 2/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5172 - loss: 1.3643 - val_accuracy: 0.5450 - val_loss: 1.2997
# Epoch 3/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.5719 - loss: 1.2235 - val_accuracy: 0.5869 - val_loss: 1.1909
# Epoch 4/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6023 - loss: 1.1438 - val_accuracy: 0.6004 - val_loss: 1.1551
# Epoch 5/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6254 - loss: 1.0794 - val_accuracy: 0.6227 - val_loss: 1.1000
# Epoch 6/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6431 - loss: 1.0298 - val_accuracy: 0.6037 - val_loss: 1.1505
# Epoch 7/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6544 - loss: 0.9950 - val_accuracy: 0.6211 - val_loss: 1.1038
# Epoch 8/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6691 - loss: 0.9496 - val_accuracy: 0.6462 - val_loss: 1.0256
# Epoch 9/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6834 - loss: 0.9157 - val_accuracy: 0.6572 - val_loss: 0.9932
# Epoch 10/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6946 - loss: 0.8841 - val_accuracy: 0.6636 - val_loss: 0.9754
# Epoch 11/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7060 - loss: 0.8561 - val_accuracy: 0.6569 - val_loss: 1.0178
# Epoch 12/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7122 - loss: 0.8303 - val_accuracy: 0.6737 - val_loss: 0.9555
# Epoch 13/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7254 - loss: 0.8002 - val_accuracy: 0.6636 - val_loss: 0.9836
# Epoch 14/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7315 - loss: 0.7790 - val_accuracy: 0.6497 - val_loss: 1.0167
# Epoch 15/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7400 - loss: 0.7539 - val_accuracy: 0.6695 - val_loss: 0.9772
# Epoch 16/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7503 - loss: 0.7233 - val_accuracy: 0.6900 - val_loss: 0.9222
# Epoch 17/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7581 - loss: 0.7015 - val_accuracy: 0.6778 - val_loss: 0.9525
# Epoch 18/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7621 - loss: 0.6916 - val_accuracy: 0.6864 - val_loss: 0.9345
# Epoch 19/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7751 - loss: 0.6552 - val_accuracy: 0.6870 - val_loss: 0.9411
# Epoch 20/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7788 - loss: 0.6378 - val_accuracy: 0.6954 - val_loss: 0.9283
# Epoch 21/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7896 - loss: 0.6128 - val_accuracy: 0.6819 - val_loss: 0.9679

# %%
#Create the Plots
plt.figure(figsize=(12,5))

# Loss plot
plt.subplot(1,2,1)
plt.plot(history_7.history['loss'], label='Train Loss')
plt.plot(history_7.history['val_loss'], label='Validation Loss')
plt.title('Cross-Entropy Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Accuracy plot
plt.subplot(1,2,2)
plt.plot(history_7.history['accuracy'], label='Train Accuracy')
plt.plot(history_7.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %%
#Evaluate Test Accuracy
test_loss, test_accuracy = model_7.evaluate(x_test_normalized, y_test)

print("Test Accuracy for model 7:", test_accuracy)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6855 - loss: 0.9389
# Test Accuracy for model 7: 0.6855000257492065

# %%
model_7.save("model_7.keras")
